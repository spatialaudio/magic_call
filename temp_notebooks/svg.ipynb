# %% [markdown]
# show different options for SVG
#
# http://dvisvgm.bplaced.net/
#
# default: `--font-format=woff,autohint`?
#
# if fonts don't show up in your viewer, try a different font format (`ttf`, `woff2`, `svg`) or try `--no-fonts`
#
# `dvisvgm` doesn't support files generated by `lualatex` yet
#
# TODO: other programs to generate SVG (`pdf2svg`, `inkscape`?)
